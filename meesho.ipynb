# %%
import pandas as pd 
a=pd.read_excel('Meesho ForwardReports 1.xlsx')
print(a.to_string())
# Out:
#     order_date   sub_order_num order_status                state     pin  gst_amount  meesho_price  shipping_charges_total  price  Unnamed: 9  Unnamed: 10
# 0   2022-08-01  406826346276_1    Delivered            Rajasthan  324008       97.62          2050                       0   2050         NaN          NaN
# 1   2022-08-06  673557263786_1       Return       Madhya Pradesh  480884       95.24          2000                     110   2110         NaN          NaN
# 2   2022-08-02  916538974169_1          rto                Assam  782435       88.62          1861                       0   1861         NaN          NaN
# 3   2022-08-05  978604039408_1    Delivered              Haryana  125004       87.96          1847                       0   1847         NaN          NaN
# 4   2022-08-05  641914233092_1    Delivered        Uttar Pradesh  231224       73.68          1547                       0   1547         NaN          NaN
# ...

# %%
print(a.head())
# Out:
#   order_date   sub_order_num order_status           state     pin  gst_amount  \
# 0 2022-08-01  406826346276_1    Delivered       Rajasthan  324008       97.62
# 1 2022-08-06  673557263786_1       Return  Madhya Pradesh  480884       95.24
# 2 2022-08-02  916538974169_1          rto           Assam  782435       88.62
# 3 2022-08-05  978604039408_1    Delivered         Haryana  125004       87.96
# 4 2022-08-05  641914233092_1    Delivered   Uttar Pradesh  231224       73.68
#
#    meesho_price  shipping_charges_total  price  Unnamed: 9  Unnamed: 10
# 0          2050                       0   2050         NaN          NaN
# 1          2000                     110   2110         NaN          NaN
# 2          1861                       0   1861         NaN          NaN
# 3          1847                       0   1847         NaN          NaN
# 4          1547                       0   1547         NaN          NaN

# %%
print(a.tail())
# Out:
#     order_date   sub_order_num order_status          state     pin  \
# 133 2022-08-29  703072596386_1      Shipped  Uttar Pradesh  211008
# 134 2022-08-29  755828660648_1      Shipped         Kerala  671121
# 135 2022-08-30  910483967612_1      Shipped          Assam  788164
# 136 2022-08-30  658416003246_1      Shipped   Chhattisgarh  491771
# 137 2022-08-31  507323371165_1      Shipped      Karnataka  560005
#
#      gst_amount  meesho_price  shipping_charges_total  price  Unnamed: 9  \
# 133       59.90          1258                       0   1286         NaN
# 134       24.72           519                       0    519         NaN
# 135       24.72           519                       0    519         NaN
# 136       24.20           508                       0    508         NaN
# 137      100.30          2106                       0   2106         NaN
#
#      Unnamed: 10
# 133          NaN
# 134          NaN
# 135          NaN
# 136          NaN
# 137          NaN

# %%
b=a.isnull().sum()
print(b[b>0])
# Out:
# Unnamed: 9     138
# Unnamed: 10    137
# dtype: int64

# %%
print(a.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_date              138 non-null    datetime64[ns]
#  1   sub_order_num           138 non-null    object
#  2   order_status            138 non-null    object
#  3   state                   138 non-null    object
#  4   pin                     138 non-null    int64
#  5   gst_amount              138 non-null    float64
#  6   meesho_price            138 non-null    int64
#  7   shipping_charges_total  138 non-null    int64
#  8   price                   138 non-null    int64
#  9   Unnamed: 9              0 non-null      float64
#  10  Unnamed: 10             1 non-null      float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 12.0+ KB
# None

# %%
print(a.describe())
# Out:
#                           order_date            pin  gst_amount  meesho_price  \
# count                            138     138.000000  138.000000    138.000000
# mean   2022-08-16 23:07:49.565217280  477676.594203   62.015507   1292.289855
# min              2022-07-29 00:00:00  110007.000000   23.480000    493.000000
# 25%              2022-08-09 00:00:00  316501.250000   62.440000   1302.750000
# 50%              2022-08-18 12:00:00  497845.500000   64.300000   1350.000000
# 75%              2022-08-25 00:00:00  670991.750000   71.405000   1491.500000
# max              2022-08-31 00:00:00  848504.000000  116.960000   2456.000000
# std                              NaN  207795.595378   20.974350    440.464241
#
#        shipping_charges_total        price  Unnamed: 9  Unnamed: 10
# count              138.000000   138.000000         0.0          1.0
# mean                69.673913  1358.572464         NaN          5.0
# ...

# %%
print(a.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# Length: 138, dtype: bool

# %%
a.drop_duplicates(inplace=True)
print(a.to_string())
a.to_excel('meesho1.xlsx')
# Out:
#     order_date   sub_order_num order_status                state     pin  gst_amount  meesho_price  shipping_charges_total  price  Unnamed: 9  Unnamed: 10
# 0   2022-08-01  406826346276_1    Delivered            Rajasthan  324008       97.62          2050                       0   2050         NaN          NaN
# 1   2022-08-06  673557263786_1       Return       Madhya Pradesh  480884       95.24          2000                     110   2110         NaN          NaN
# 2   2022-08-02  916538974169_1          rto                Assam  782435       88.62          1861                       0   1861         NaN          NaN
# 3   2022-08-05  978604039408_1    Delivered              Haryana  125004       87.96          1847                       0   1847         NaN          NaN
# 4   2022-08-05  641914233092_1    Delivered        Uttar Pradesh  231224       73.68          1547                       0   1547         NaN          NaN
# ...
